# %% [markdown]
# # SwiGLU Feed Forward

# %% [markdown]
# From Llama 1 & 2 paper: "We replace the ReLU non-linearity by the SwiGLU activation function, introduced by Shazeer (2020) to improve the performance. We use a dimension of $\frac{2}{3} 4d$ instead of $4d$ as in PaLM."

# %%
3e-4
# Out:
# 0.0003
