# %%
#TODO make sure this renders in the github repo

# %% [markdown]
# # Training an LLM

# %%
# # TODO add to training loop
# # In train.py loop
# for x_ids, y_ids in dataloader:
#     # 1. Generate the advanced document mask for this specific batch
#     batch_mask = create_causal_doc_mask(x_ids, eod_token_id=cfg.doc_end_token_id)
    
#     # 2. Forward pass, passing the mask
#     # We set is_causal=False inside the attention block, 
#     # because our 'batch_mask' tensor already includes the triangular causal component.
#     output = gqa(x_ids, freqs_cis, mask=batch_mask)
#     # ... rest of loop

# %%
# The final normalization before the output linear
        # self.final_norm = RMSNorm(cfg.hidden_size, eps=cfg.rms_norm_eps)
# And final softmax
